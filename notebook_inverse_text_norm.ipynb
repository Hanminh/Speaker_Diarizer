# %%
from nemo_text_processing.inverse_text_normalization.inverse_normalize import InverseNormalizer
inverse_normalizer = InverseNormalizer(lang='vi')
spoken = "ứng dụng ti vi một sáu mươi"
un_normalized = inverse_normalizer.inverse_normalize(spoken, verbose=True)
print(un_normalized)
# Out:
#  NeMo-text-processing :: INFO     :: Creating ClassifyFst grammars.
#  NeMo-text-processing :: DEBUG    :: tokens { name: "ứng" } tokens { name: "dụng" } tokens { name: "ti" } tokens { name: "vi" } tokens { name: "một" } tokens { cardinal { integer: "60" } }
# ứng dụng ti vi một 60
